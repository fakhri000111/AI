# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %% [markdown]
# read data

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# remove unwanted data

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %% [markdown]
# new data

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# # analyze geography colums

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %% [markdown]
# represent two column in one column and data in binary

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %% [markdown]
# split input and actual output

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# **normalize data**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %% [markdown]
# # constract model layout

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
#input layer 
model.add(Dense(11,activation='sigmoid',input_dim=11))
#hidden layer
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(5,activation='sigmoid'))
#output layer
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 11)                132
# _________________________________________________________________
# dense_41 (Dense)             (None, 11)                132
# _________________________________________________________________
# dense_42 (Dense)             (None, 5)                 60
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 330
# Trainable params: 330
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Back Propogation

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,batch_size=50,epochs=20,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/20
# 128/128 [==============================] - 1s 4ms/step - loss: 0.6099 - accuracy: 0.7466 - val_loss: 0.5439 - val_accuracy: 0.7969
# Epoch 2/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7958 - val_loss: 0.5120 - val_accuracy: 0.7969
# Epoch 3/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7958 - val_loss: 0.5056 - val_accuracy: 0.7969
# Epoch 4/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 5/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5037 - val_accuracy: 0.7969
# Epoch 6/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7958 - val_loss: 0.5035 - val_accuracy: 0.7969
# Epoch 7/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.7958 - val_loss: 0.5033 - val_accuracy: 0.7969
# Epoch 8/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5053 - accuracy: 0.7958 - val_loss: 0.5031 - val_accuracy: 0.7969
# Epoch 9/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.7958 - val_loss: 0.5027 - val_accuracy: 0.7969
# Epoch 10/20
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7958 - val_loss: 0.5023 - val_accuracy: 0.7969
# Epoch 11/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7958 - val_loss: 0.5018 - val_accuracy: 0.7969
# Epoch 12/20
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5040 - accuracy: 0.7958 - val_loss: 0.5014 - val_accuracy: 0.7969
# Epoch 13/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7958 - val_loss: 0.5007 - val_accuracy: 0.7969
# Epoch 14/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5031 - accuracy: 0.7958 - val_loss: 0.5002 - val_accuracy: 0.7969
# Epoch 15/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7958 - val_loss: 0.4996 - val_accuracy: 0.7969
# Epoch 16/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.7958 - val_loss: 0.4990 - val_accuracy: 0.7969
# Epoch 17/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4986 - val_accuracy: 0.7969
# Epoch 18/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.7958 - val_loss: 0.4981 - val_accuracy: 0.7969
# Epoch 19/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5012 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 20/20
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5009 - accuracy: 0.7958 - val_loss: 0.4973 - val_accuracy: 0.7969

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[0.20081702],
#        [0.22931877],
#        [0.22931877],
#        ...,
#        [0.22931877],
#        [0.23438129],
#        [0.20081702]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
